# %% [markdown]
# # Artificial Intelligence Nanodegree
# ## Machine Translation Project
# In this notebook, sections that end with **'(IMPLEMENTATION)'** in the header indicate that the following blocks of code will require additional functionality which you must provide. Please be sure to read the instructions carefully!
#
# ## Introduction
# In this notebook, you will build a deep neural network that functions as part of an end-to-end machine translation pipeline. Your completed pipeline will accept English text as input and return the French translation.
#
# - **Preprocess** - You'll convert text to sequence of integers.
# - **Models** Create models which accepts a sequence of integers as input and returns a probability distribution over possible translations. After learning about the basic types of neural networks that are often used for machine translation, you will engage in your own investigations, to design your own model!
# - **Prediction** Run the model on English text.

# %%
# %load_ext autoreload
# %aimport helper, tests
# %autoreload 2

# %%
import collections

import helper
import numpy as np
import project_tests as tests
import nltk
from functools import reduce


try: 
    from keras.preprocessing.text import Tokenizer
    from keras.preprocessing.sequence import pad_sequences
    from keras.models import Model, Sequential
    from keras.layers import GRU, Input, Dense, TimeDistributed, Activation, RepeatVector, Bidirectional, LSTM
    from keras.layers import LSTM, Reshape, Dropout
    from keras.layers.embeddings import Embedding
    from keras.optimizers import Adam
    from keras.losses import sparse_categorical_crossentropy
except ImportError:
    print("Using Tensor Flow 2...")
    from tensorflow.keras.preprocessing.text import Tokenizer
    from tensorflow.keras.preprocessing.sequence import pad_sequences
    from tensorflow.keras.models import Model, Sequential
    from tensorflow.keras.layers import GRU, Input, Dense, TimeDistributed, Activation, RepeatVector, Bidirectional
    from tensorflow.keras.layers import LSTM, Reshape, Dropout
    from tensorflow.keras.layers import Embedding
    from tensorflow.keras.optimizers import Adam
    from tensorflow.keras.losses import sparse_categorical_crossentropy
# Out:
# Using Tensor Flow 2...

# %% [markdown]
# ### Verify access to the GPU
# The following test applies only if you expect to be using a GPU, e.g., while running in a Udacity Workspace or using an AWS instance with GPU support. Run the next cell, and verify that the device_type is "GPU".
# - If the device is not GPU & you are running from a Udacity Workspace, then save your workspace with the icon at the top, then click "enable" at the bottom of the workspace.
# - If the device is not GPU & you are running from an AWS instance, then refer to the cloud computing instructions in the classroom to verify your setup steps.

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 6665772708393685516
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6963920896
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 15234556797218876678
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1"
# xla_global_id: 416903419
# ]

# %% [markdown]
# ## Dataset
# We begin by investigating the dataset that will be used to train and evaluate your pipeline.  The most common datasets used for machine translation are from [WMT](http://www.statmt.org/).  However, that will take a long time to train a neural network on.  We'll be using a dataset we created for this project that contains a small vocabulary.  You'll be able to train your model in a reasonable time with this dataset.
# ### Load Data
# The data is located in `data/small_vocab_en` and `data/small_vocab_fr`. The `small_vocab_en` file contains English sentences with their French translations in the `small_vocab_fr` file. Load the English and French data from these files from running the cell below.

# %%
# Load English data
english_sentences = helper.load_data('data/small_vocab_en')
# Load French data
french_sentences = helper.load_data('data/small_vocab_fr')

print('Dataset Loaded')
# Out:
# Dataset Loaded

# %% [markdown]
# ### Files
# Each line in `small_vocab_en` contains an English sentence with the respective translation in each line of `small_vocab_fr`.  View the first two lines from each file.

# %%
for sample_i in range(2):
    print('small_vocab_en Line {}:  {}'.format(sample_i + 1, english_sentences[sample_i]))
    print('small_vocab_fr Line {}:  {}'.format(sample_i + 1, french_sentences[sample_i]))
# Out:
# small_vocab_en Line 1:  new jersey is sometimes quiet during autumn , and it is snowy in april .
# small_vocab_fr Line 1:  new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# small_vocab_en Line 2:  the united states is usually chilly during july , and it is usually freezing in november .
# small_vocab_fr Line 2:  les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .

# %% [markdown]
# From looking at the sentences, you can see they have been preprocessed already.  The puncuations have been delimited using spaces. All the text have been converted to lowercase.  This should save you some time, but the text requires more preprocessing.
# ### Vocabulary
# The complexity of the problem is determined by the complexity of the vocabulary.  A more complex vocabulary is a more complex problem.  Let's look at the complexity of the dataset we'll be working with.

# %%
english_words_counter = collections.Counter([word for sentence in english_sentences for word in sentence.split()])
french_words_counter = collections.Counter([word for sentence in french_sentences for word in sentence.split()])

print('{} English words.'.format(len([word for sentence in english_sentences for word in sentence.split()])))
print('{} unique English words.'.format(len(english_words_counter)))
print('10 Most common words in the English dataset:')
print('"' + '" "'.join(list(zip(*english_words_counter.most_common(10)))[0]) + '"')
print()
print('{} French words.'.format(len([word for sentence in french_sentences for word in sentence.split()])))
print('{} unique French words.'.format(len(french_words_counter)))
print('10 Most common words in the French dataset:')
print('"' + '" "'.join(list(zip(*french_words_counter.most_common(10)))[0]) + '"')
# Out:
# 1823250 English words.
# 227 unique English words.
# 10 Most common words in the English dataset:
# "is" "," "." "in" "it" "during" "the" "but" "and" "sometimes"
#
# 1961295 French words.
# 355 unique French words.
# 10 Most common words in the French dataset:
# "est" "." "," "en" "il" "les" "mais" "et" "la" "parfois"

# %% [markdown]
# For comparison, _Alice's Adventures in Wonderland_ contains 2,766 unique words of a total of 15,500 words.
# ## Preprocess
# For this project, you won't use text data as input to your model. Instead, you'll convert the text into sequences of integers using the following preprocess methods:
# 1. Tokenize the words into ids
# 2. Add padding to make all the sequences the same length.
#
# Time to start preprocessing the data...
# ### Tokenize (IMPLEMENTATION)
# For a neural network to predict on text data, it first has to be turned into data it can understand. Text data like "dog" is a sequence of ASCII character encodings.  Since a neural network is a series of multiplication and addition operations, the input data needs to be number(s).
#
# We can turn each character into a number or each word into a number.  These are called character and word ids, respectively.  Character ids are used for character level models that generate text predictions for each character.  A word level model uses word ids that generate text predictions for each word.  Word level models tend to learn better, since they are lower in complexity, so we'll use those.
#
# Turn each sentence into a sequence of words ids using Keras's [`Tokenizer`](https://keras.io/preprocessing/text/#tokenizer) function. Use this function to tokenize `english_sentences` and `french_sentences` in the cell below.
#
# Running the cell will run `tokenize` on sample data and show output for debugging.

# %%
def tokenize(x):
    """
    Tokenize x
    :param x: List of sentences/strings to be tokenized
    :return: Tuple of (tokenized x data, tokenizer used to tokenize x)
    """
    # TODO: Implement
    tk = Tokenizer()
    tk.fit_on_texts(x)
    return tk.texts_to_sequences(x), tk
tests.test_tokenize(tokenize)

# Tokenize Example output
text_sentences = [
    'The quick brown fox jumps over the lazy dog .',
    'By Jove , my quick study of lexicography won a prize .',
    'This is a short sentence .']
text_tokenized, text_tokenizer = tokenize(text_sentences)
print(text_tokenizer.word_index)
print()
for sample_i, (sent, token_sent) in enumerate(zip(text_sentences, text_tokenized)):
    print('Sequence {} in x'.format(sample_i + 1))
    print('  Input:  {}'.format(sent))
    print('  Output: {}'.format(token_sent))
# Out:
# {'the': 1, 'quick': 2, 'a': 3, 'brown': 4, 'fox': 5, 'jumps': 6, 'over': 7, 'lazy': 8, 'dog': 9, 'by': 10, 'jove': 11, 'my': 12, 'study': 13, 'of': 14, 'lexicography': 15, 'won': 16, 'prize': 17, 'this': 18, 'is': 19, 'short': 20, 'sentence': 21}
#
# Sequence 1 in x
#   Input:  The quick brown fox jumps over the lazy dog .
#   Output: [1, 2, 4, 5, 6, 7, 1, 8, 9]
# Sequence 2 in x
#   Input:  By Jove , my quick study of lexicography won a prize .
#   Output: [10, 11, 12, 2, 13, 14, 15, 16, 3, 17]
# Sequence 3 in x
#   Input:  This is a short sentence .
#   Output: [18, 19, 3, 20, 21]

# %% [markdown]
# ### Padding (IMPLEMENTATION)
# When batching the sequence of word ids together, each sequence needs to be the same length.  Since sentences are dynamic in length, we can add padding to the end of the sequences to make them the same length.
#
# Make sure all the English sequences have the same length and all the French sequences have the same length by adding padding to the **end** of each sequence using Keras's [`pad_sequences`](https://keras.io/preprocessing/sequence/#pad_sequences) function.

# %%
def pad(x, length=None):
    """
    Pad x
    :param x: List of sequences.
    :param length: Length to pad the sequence to.  If None, use length of longest sequence in x.
    :return: Padded numpy array of sequences
    """
    # TODO: Implement
    def get_max_len(x):
        length = 0
        for entry in x:
            if len(entry) > length:
                length = len(entry)
        return length

    if length is None:
        length = get_max_len(x)

    return pad_sequences(x, maxlen=length, padding='post')
tests.test_pad(pad)

# Pad Tokenized output
test_pad = pad(text_tokenized)
for sample_i, (token_sent, pad_sent) in enumerate(zip(text_tokenized, test_pad)):
    print('Sequence {} in x'.format(sample_i + 1))
    print('  Input:  {}'.format(np.array(token_sent)))
    print('  Output: {}'.format(pad_sent))
# Out:
# Sequence 1 in x
#   Input:  [1 2 4 5 6 7 1 8 9]
#   Output: [1 2 4 5 6 7 1 8 9 0]
# Sequence 2 in x
#   Input:  [10 11 12  2 13 14 15 16  3 17]
#   Output: [10 11 12  2 13 14 15 16  3 17]
# Sequence 3 in x
#   Input:  [18 19  3 20 21]
#   Output: [18 19  3 20 21  0  0  0  0  0]

# %% [markdown]
# ### Preprocess Pipeline
# Your focus for this project is to build neural network architecture, so we won't ask you to create a preprocess pipeline.  Instead, we've provided you with the implementation of the `preprocess` function.

# %%
def preprocess(x, y):
    """
    Preprocess x and y
    :param x: Feature List of sentences
    :param y: Label List of sentences
    :return: Tuple of (Preprocessed x, Preprocessed y, x tokenizer, y
        tokenizer)
    """
    preprocess_x, x_tk = tokenize(x)
    preprocess_y, y_tk = tokenize(y)

    preprocess_x = pad(preprocess_x)
    preprocess_y = pad(preprocess_y)

    # Keras's sparse_categorical_crossentropy function requires the labels to
    # be in 3 dimensions
    preprocess_y = preprocess_y.reshape(*preprocess_y.shape, 1)

    return preprocess_x, preprocess_y, x_tk, y_tk

(
    preproc_english_sentences, preproc_french_sentences,
    english_tokenizer, french_tokenizer
) = preprocess(english_sentences, french_sentences)
    
max_english_sequence_length = preproc_english_sentences.shape[1]
max_french_sequence_length = preproc_french_sentences.shape[1]
english_vocab_size = len(english_tokenizer.word_index)
french_vocab_size = len(french_tokenizer.word_index)

print('Data Preprocessed')
print("Max English sentence length:", max_english_sequence_length)
print("Max French sentence length:", max_french_sequence_length)
print("English vocabulary size:", english_vocab_size)
print("French vocabulary size:", french_vocab_size)
# Out:
# Data Preprocessed
# Max English sentence length: 15
# Max French sentence length: 21
# English vocabulary size: 199
# French vocabulary size: 344

# %% [markdown]
# ## Models
# In this section, you will experiment with various neural network architectures.
# You will begin by training four relatively simple architectures.
# - Model 1 is a simple RNN
# - Model 2 is a RNN with Embedding
# - Model 3 is a Bidirectional RNN
# - Model 4 is an optional Encoder-Decoder RNN
#
# After experimenting with the four simple architectures, you will construct a deeper architecture that is designed to outperform all four models.
# ### Ids Back to Text
# The neural network will be translating the input to words ids, which isn't the final form we want.  We want the French translation.  The function `logits_to_text` will bridge the gap between the logits from the neural network to the French translation.  You'll be using this function to better understand the output of the neural network.

# %%
def logits_to_text(logits, tokenizer):
    """
    Turn logits from a neural network into text using the tokenizer
    :param logits: Logits from a neural network
    :param tokenizer: Keras Tokenizer fit on the labels
    :return: String that represents the text of the logits
    """
    index_to_words = {id: word for word, id in tokenizer.word_index.items()}
    index_to_words[0] = '<PAD>'

    return ' '.join(
        [index_to_words[prediction] for prediction in np.argmax(logits, 1)]
    )

print('`logits_to_text` function loaded.')
# Out:
# `logits_to_text` function loaded.

# %% [markdown]
# ### Model 1: RNN (IMPLEMENTATION)
# ![RNN](images/rnn.png)
# A basic RNN model is a good baseline for sequence data.  In this model, you'll build a RNN that translates English to French.

# %%
def simple_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    """
    Build and train a basic RNN on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """
    # TODO: Build the layers
    learning_rate = 1e-3
    gru_size = 128
    model = Sequential([
        GRU(gru_size, input_shape=input_shape[1:], return_sequences=True),
        TimeDistributed(Dense(french_vocab_size, activation="softmax")),
    ])
    # input_seq = Input(input_shape[1:])
    # rnn = GRU(gru_size, return_sequences=True)(input_seq)
    # logits = TimeDistributed(Dense(french_vocab_size))(rnn)
    # model = Model(input_seq, Activation("softmax")(logits))


    model.compile(loss=sparse_categorical_crossentropy,
                  optimizer=Adam(learning_rate),
                  metrics=['accuracy'])
    print(model.summary())
    return model
tests.test_simple_model(simple_model)

# Reshaping the input to work with a basic RNN
tmp_x = pad(preproc_english_sentences, max_french_sequence_length)
tmp_x = tmp_x.reshape((-1, preproc_french_sentences.shape[-2], 1))

# Train the neural network
simple_rnn_model = simple_model(
    tmp_x.shape,
    max_french_sequence_length,
    english_vocab_size,
    french_vocab_size)
simple_rnn_model.fit(tmp_x, preproc_french_sentences, batch_size=1024, epochs=10, validation_split=0.2)

# Print prediction(s)
print(logits_to_text(simple_rnn_model.predict(tmp_x[:1])[0], french_tokenizer))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 21, 128)           50304
#
#  time_distributed (TimeDistr  (None, 21, 344)          44376
#  ibuted)
#
# =================================================================
# Total params: 94,680
# Trainable params: 94,680
# Non-trainable params: 0
# _________________________________________________________________
# None
# New Version of keras - Sequential has all expected attrs...
# Trying Tensorflow 2 version of keras...
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 21, 128)           50304
#
#  time_distributed_1 (TimeDis  (None, 21, 344)          44376
#  tributed)
#
# =================================================================
# Total params: 94,680
# Trainable params: 94,680
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 108/108 [==============================] - 8s 28ms/step - loss: 2.9695 - accuracy: 0.4402 - val_loss: nan - val_accuracy: 0.4870
# Epoch 2/10
# 108/108 [==============================] - 2s 22ms/step - loss: 2.0014 - accuracy: 0.5390 - val_loss: nan - val_accuracy: 0.5684
# Epoch 3/10
# 108/108 [==============================] - 2s 22ms/step - loss: 1.6688 - accuracy: 0.5806 - val_loss: nan - val_accuracy: 0.5903
# Epoch 4/10
# 108/108 [==============================] - 2s 22ms/step - loss: 1.5202 - accuracy: 0.6005 - val_loss: nan - val_accuracy: 0.6085
# Epoch 5/10
# 108/108 [==============================] - 2s 22ms/step - loss: 1.4236 - accuracy: 0.6134 - val_loss: nan - val_accuracy: 0.6211
# Epoch 6/10
# 108/108 [==============================] - 2s 23ms/step - loss: 1.3471 - accuracy: 0.6272 - val_loss: nan - val_accuracy: 0.6363
# Epoch 7/10
# 108/108 [==============================] - 2s 22ms/step - loss: 1.2825 - accuracy: 0.6393 - val_loss: nan - val_accuracy: 0.6471
# Epoch 8/10
# 108/108 [==============================] - 2s 22ms/step - loss: 1.2298 - accuracy: 0.6485 - val_loss: nan - val_accuracy: 0.6542
# Epoch 9/10
# 108/108 [==============================] - 2s 23ms/step - loss: 1.1841 - accuracy: 0.6577 - val_loss: nan - val_accuracy: 0.6602
# Epoch 10/10
# 108/108 [==============================] - 2s 22ms/step - loss: 1.1479 - accuracy: 0.6636 - val_loss: nan - val_accuracy: 0.6656
# paris jersey est parfois calme en mois de il il est est en en <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %% [markdown]
# ### Model 2: Embedding (IMPLEMENTATION)
# ![RNN](images/embedding.png)
# You've turned the words into ids, but there's a better representation of a word.  This is called word embeddings.  An embedding is a vector representation of the word that is close to similar words in n-dimensional space, where the n represents the size of the embedding vectors.
#
# In this model, you'll create a RNN model using embedding.

# %%
def embed_model(
    input_shape, output_sequence_length, english_vocab_size, french_vocab_size
):
    """
    Build and train a RNN model using word embedding on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """
    # TODO: Implement
    h_dim = 128
    learning_rate = 1e-3
    model = Sequential([
        Embedding(
            input_length=input_shape[1],
            input_dim=english_vocab_size,
            output_dim=h_dim
        ),
        GRU(h_dim, return_sequences=True),
        TimeDistributed(Dense(french_vocab_size, activation="softmax")),
    ])

    model.compile(loss=sparse_categorical_crossentropy,
                  optimizer=Adam(learning_rate),
                  metrics=['accuracy'])
    print(model.summary())
    return model
tests.test_embed_model(embed_model)


# TODO: Reshape the input
tmp_x = pad(preproc_english_sentences, max_french_sequence_length)

# TODO: Train the neural network
embedded_rnn_model = embed_model(
    tmp_x.shape,
    max_french_sequence_length,
    english_vocab_size,
    french_vocab_size)

embedded_rnn_model.fit(
    tmp_x,
    preproc_french_sentences,
    batch_size=1024,
    epochs=10,
    validation_split=0.2
)


# TODO: Print prediction(s)
print(
    logits_to_text(embedded_rnn_model.predict(tmp_x[:1])[0], french_tokenizer)
)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 21, 128)           25472
#
#  gru_2 (GRU)                 (None, 21, 128)           99072
#
#  time_distributed_2 (TimeDis  (None, 21, 344)          44376
#  tributed)
#
# =================================================================
# Total params: 168,920
# Trainable params: 168,920
# Non-trainable params: 0
# _________________________________________________________________
# None
# New Version of keras - Sequential has all expected attrs...
# Trying Tensorflow 2 version of keras...
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 21, 128)           25472
#
#  gru_3 (GRU)                 (None, 21, 128)           99072
#
#  time_distributed_3 (TimeDis  (None, 21, 344)          44376
#  tributed)
#
# =================================================================
# Total params: 168,920
# Trainable params: 168,920
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 108/108 [==============================] - 4s 28ms/step - loss: 3.3391 - accuracy: 0.4089 - val_loss: nan - val_accuracy: 0.4640
# Epoch 2/10
# 108/108 [==============================] - 3s 26ms/step - loss: 2.0435 - accuracy: 0.5491 - val_loss: nan - val_accuracy: 0.6267
# Epoch 3/10
# 108/108 [==============================] - 3s 26ms/step - loss: 1.2840 - accuracy: 0.6847 - val_loss: nan - val_accuracy: 0.7387
# Epoch 4/10
# 108/108 [==============================] - 3s 26ms/step - loss: 0.9380 - accuracy: 0.7646 - val_loss: nan - val_accuracy: 0.7850
# Epoch 5/10
# 108/108 [==============================] - 3s 26ms/step - loss: 0.7387 - accuracy: 0.7999 - val_loss: nan - val_accuracy: 0.8160
# Epoch 6/10
# 108/108 [==============================] - 3s 26ms/step - loss: 0.6186 - accuracy: 0.8245 - val_loss: nan - val_accuracy: 0.8366
# Epoch 7/10
# 108/108 [==============================] - 3s 26ms/step - loss: 0.5381 - accuracy: 0.8441 - val_loss: nan - val_accuracy: 0.8527
# Epoch 8/10
# 108/108 [==============================] - 3s 26ms/step - loss: 0.4805 - accuracy: 0.8586 - val_loss: nan - val_accuracy: 0.8662
# Epoch 9/10
# 108/108 [==============================] - 3s 26ms/step - loss: 0.4368 - accuracy: 0.8696 - val_loss: nan - val_accuracy: 0.8756
# Epoch 10/10
# 108/108 [==============================] - 3s 26ms/step - loss: 0.4021 - accuracy: 0.8791 - val_loss: nan - val_accuracy: 0.8844
# new jersey est parfois calme en l' et il il est neigeux en avril <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %% [markdown]
# ### Model 3: Bidirectional RNNs (IMPLEMENTATION)
# ![RNN](images/bidirectional.png)
# One restriction of a RNN is that it can't see the future input, only the past.  This is where bidirectional recurrent neural networks come in.  They are able to see the future data.

# %%
def bd_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    """
    Build and train a bidirectional RNN model on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """
    # TODO: Implement
    h_dim = 128
    learning_rate = 1e-3
    model = Sequential([
        Reshape(
            (reduce(lambda x,y: x*y, input_shape[1:]),),
            input_shape=input_shape[1:]
        ),
        Embedding(
            input_length=input_shape[1],
            input_dim=english_vocab_size,
            output_dim=h_dim
        ),
         Bidirectional(GRU(
            h_dim,
            input_shape=input_shape[1:],
            return_sequences=True
        )),
        TimeDistributed(Dense(french_vocab_size, activation="softmax")),
    ])

    model.compile(loss=sparse_categorical_crossentropy,
                  optimizer=Adam(learning_rate),
                  metrics=['accuracy'])
    print(model.summary())
    return model
tests.test_bd_model(bd_model)


# TODO: Train and Print prediction(s)
# TODO: Reshape the input
tmp_x = pad(preproc_english_sentences, max_french_sequence_length)

# TODO: Train the neural network
bd_rnn_model = bd_model(
    tmp_x.shape,
    max_french_sequence_length,
    english_vocab_size,
    french_vocab_size)

bd_rnn_model.fit(
    tmp_x,
    preproc_french_sentences,
    batch_size=1024,
    epochs=10,
    validation_split=0.2
)


# TODO: Print prediction(s)
print(
    logits_to_text(bd_rnn_model.predict(tmp_x[:1])[0], french_tokenizer)
)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 21)                0
#
#  embedding_2 (Embedding)     (None, 21, 128)           25472
#
#  bidirectional (Bidirectiona  (None, 21, 256)          198144
#  l)
#
#  time_distributed_4 (TimeDis  (None, 21, 344)          88408
#  tributed)
#
# =================================================================
# Total params: 312,024
# Trainable params: 312,024
# Non-trainable params: 0
# _________________________________________________________________
# None
# New Version of keras - Sequential has all expected attrs...
# Trying Tensorflow 2 version of keras...
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_1 (Reshape)         (None, 21)                0
#
#  embedding_3 (Embedding)     (None, 21, 128)           25472
#
#  bidirectional_1 (Bidirectio  (None, 21, 256)          198144
#  nal)
#
#  time_distributed_5 (TimeDis  (None, 21, 344)          88408
#  tributed)
#
# =================================================================
# Total params: 312,024
# Trainable params: 312,024
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 108/108 [==============================] - 7s 41ms/step - loss: 3.0374 - accuracy: 0.4524 - val_loss: nan - val_accuracy: 0.5274
# Epoch 2/10
# 108/108 [==============================] - 4s 37ms/step - loss: 1.6090 - accuracy: 0.6201 - val_loss: nan - val_accuracy: 0.7119
# Epoch 3/10
# 108/108 [==============================] - 4s 37ms/step - loss: 1.0054 - accuracy: 0.7491 - val_loss: nan - val_accuracy: 0.7763
# Epoch 4/10
# 108/108 [==============================] - 4s 37ms/step - loss: 0.7483 - accuracy: 0.7968 - val_loss: nan - val_accuracy: 0.8162
# Epoch 5/10
# 108/108 [==============================] - 4s 37ms/step - loss: 0.5773 - accuracy: 0.8354 - val_loss: nan - val_accuracy: 0.8517
# Epoch 6/10
# 108/108 [==============================] - 4s 37ms/step - loss: 0.4671 - accuracy: 0.8622 - val_loss: nan - val_accuracy: 0.8720
# Epoch 7/10
# 108/108 [==============================] - 4s 37ms/step - loss: 0.3917 - accuracy: 0.8827 - val_loss: nan - val_accuracy: 0.8905
# Epoch 8/10
# 108/108 [==============================] - 4s 37ms/step - loss: 0.3368 - accuracy: 0.8988 - val_loss: nan - val_accuracy: 0.9055
# Epoch 9/10
# 108/108 [==============================] - 4s 37ms/step - loss: 0.2959 - accuracy: 0.9114 - val_loss: nan - val_accuracy: 0.9156
# Epoch 10/10
# 108/108 [==============================] - 4s 37ms/step - loss: 0.2638 - accuracy: 0.9211 - val_loss: nan - val_accuracy: 0.9228
# new jersey est parfois calme au l' et il et il en avril <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %% [markdown]
# ### Model 4: Encoder-Decoder (OPTIONAL)
# Time to look at encoder-decoder models.  This model is made up of an encoder and decoder. The encoder creates a matrix representation of the sentence.  The decoder takes this matrix as input and predicts the translation as output.
#
# Create an encoder-decoder model in the cell below.

# %%
def encdec_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    """
    Build and train an encoder-decoder model on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """
    # OPTIONAL: Implement
    _, *in_shape = input_shape # first dim is batch and is passed as None
    h_dim = 128
    learning_rate = 1e-3
    p_dropout = 0.2
    model = Sequential(layers=[
        GRU(
            units=h_dim,
            return_sequences=False,
            input_shape=in_shape
        ),
        RepeatVector(output_sequence_length),
        GRU(
            units=h_dim,
            input_shape=(None, output_sequence_length),
            return_sequences=True),

        # Dropout(p_dropout),
        TimeDistributed(Dense(french_vocab_size, activation="relu")),
        TimeDistributed(Dense(french_vocab_size, activation="softmax")),
    ])

    model.compile(loss=sparse_categorical_crossentropy,
                  optimizer=Adam(learning_rate),
                  metrics=['accuracy'])
    print(model.summary())
    return model
tests.test_encdec_model(encdec_model)



# OPTIONAL: Train and Print prediction(s)
tmp_x = pad(preproc_english_sentences, max_english_sequence_length)
tmp_x = tmp_x.reshape((-1, max_english_sequence_length, 1))

# tmp_x = pad(preproc_english_sentences, max_french_sequence_length)
# tmp_x = tmp_x.reshape((-1, max_french_sequence_length, 1))

# TODO: Train the neural network
encdec_rnn_model = encdec_model(
    tmp_x.shape,
    max_french_sequence_length,
    english_vocab_size,
    french_vocab_size)

encdec_rnn_model.fit(
    tmp_x,
    preproc_french_sentences,
    batch_size=1024,
    epochs=10,
    validation_split=0.2
)


# TODO: Print prediction(s)
print(
    logits_to_text(encdec_rnn_model.predict(tmp_x[:1])[0], french_tokenizer)
)
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_45 (GRU)                (None, 128)               50304
#
#  repeat_vector_20 (RepeatVec  (None, 21, 128)          0
#  tor)
#
#  gru_46 (GRU)                (None, 21, 128)           99072
#
#  time_distributed_42 (TimeDi  (None, 21, 344)          44376
#  stributed)
#
#  time_distributed_43 (TimeDi  (None, 21, 344)          118680
#  stributed)
#
# =================================================================
# Total params: 312,432
# Trainable params: 312,432
# Non-trainable params: 0
# _________________________________________________________________
# None
# New Version of keras - Sequential has all expected attrs...
# Trying Tensorflow 2 version of keras...
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_47 (GRU)                (None, 128)               50304
#
#  repeat_vector_21 (RepeatVec  (None, 21, 128)          0
#  tor)
#
#  gru_48 (GRU)                (None, 21, 128)           99072
#
#  time_distributed_44 (TimeDi  (None, 21, 344)          44376
#  stributed)
#
#  time_distributed_45 (TimeDi  (None, 21, 344)          118680
#  stributed)
#
# =================================================================
# Total params: 312,432
# Trainable params: 312,432
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 108/108 [==============================] - 6s 39ms/step - loss: 2.8682 - accuracy: 0.4501 - val_loss: nan - val_accuracy: 0.4975
# Epoch 2/10
# 108/108 [==============================] - 4s 35ms/step - loss: 2.0690 - accuracy: 0.5243 - val_loss: nan - val_accuracy: 0.5584racy:
# Epoch 3/10
# 108/108 [==============================] - 4s 35ms/step - loss: 1.6656 - accuracy: 0.5690 - val_loss: nan - val_accuracy: 0.5836
# Epoch 4/10
# 108/108 [==============================] - 4s 35ms/step - loss: 1.5003 - accuracy: 0.5922 - val_loss: nan - val_accuracy: 0.6038
# Epoch 5/10
# 108/108 [==============================] - 4s 35ms/step - loss: 1.4171 - accuracy: 0.6086 - val_loss: nan - val_accuracy: 0.6145: 0s - loss: 1.4240 - accura - ETA: 0s - loss: 1.421
# Epoch 6/10
# 108/108 [==============================] - 4s 35ms/step - loss: 1.3648 - accuracy: 0.6209 - val_loss: nan - val_accuracy: 0.6267
# Epoch 7/10
# 108/108 [==============================] - 4s 35ms/step - loss: 1.3335 - accuracy: 0.6266 - val_loss: nan - val_accuracy: 0.6326 1.3382 - accuracy: 0. - ETA: 0s - loss: 1.3376
# Epoch 8/10
# 108/108 [==============================] - 4s 35ms/step - loss: 1.3013 - accuracy: 0.6322 - val_loss: nan - val_accuracy: 0.6336
# Epoch 9/10
# 108/108 [==============================] - 4s 35ms/step - loss: 1.2767 - accuracy: 0.6353 - val_loss: nan - val_accuracy: 0.6380s: 1.2936 - accuracy - ETA: 2s - los
# Epoch 10/10
# 108/108 [==============================] - 4s 35ms/step - loss: 1.2491 - accuracy: 0.6385 - val_loss: nan - val_accuracy: 0.6406
# new jersey est parfois chaud en mois et il est est en en <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %% [markdown]
# ### Model 5: Custom (IMPLEMENTATION)
# Use everything you learned from the previous models to create a model that incorporates embedding and a bidirectional rnn into one model.

# %%
def model_final(
    input_shape,
    output_sequence_length,
    english_vocab_size,
    french_vocab_size):
    """
    Build and train a model that incorporates embedding, encoder-decoder, and
    bidirectional RNN on x and y

    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """
    # TODO: Implement
    h_dim = 128
    learning_rate = 1e-3
    p_drop = 0.2
    _, *in_shape = input_shape
    model = Sequential([
        Embedding(
            # input_length=in_shape,
            input_shape=in_shape,
            input_dim=english_vocab_size,
            output_dim=h_dim,
            # mask_zero=True
        ),
        Bidirectional(GRU(
            units=h_dim,
            input_shape=in_shape,
            return_sequences=False,  # return_sequences=True,
        )),
        RepeatVector(output_sequence_length),
        Bidirectional(GRU(
            units=h_dim,
            input_shape=(None, output_sequence_length),
            return_sequences=True
        )),
        Dropout(p_drop),
        TimeDistributed(Dense(french_vocab_size, activation="relu")),
        TimeDistributed(Dense(french_vocab_size, activation="softmax")),
    ])

    model.compile(loss=sparse_categorical_crossentropy,
                  optimizer=Adam(learning_rate),
                  metrics=['accuracy'])
    print(model.summary())
    return model

tests.test_model_final(model_final)
# ACM: your test does not account for preprocessing the vector. Looking at the 
#      suggestions on Knowledge.udacity.com a common solution is to prepad the
#      input vector to the output size - I have decided to execute on this
#      implementation suggestion since this will not impact the meaning of the
#      english sentences and will simplify model construction
# ACM: [UPDATE] - Found out how to input the correct input and output layers!
#   The trick was the repeat vector


print('Final Model Loaded')
# TODO: Train the final model
tmp_x = pad(preproc_english_sentences, max_english_sequence_length)

# tmp_x = tmp_x.reshape((-1, max_french_sequence_length, 1))
# tmp_x = pad(preproc_english_sentences, max_french_sequence_length)
# tmp_x = tmp_x.reshape((-1, max_french_sequence_length, 1))
# print(tmp_x.shape)

# TODO: Train the neural network
my_final_model = model_final(
    tmp_x.shape,
    max_french_sequence_length,
    english_vocab_size,
    french_vocab_size)

history = my_final_model.fit(
    tmp_x,
    preproc_french_sentences,
    batch_size=1024,
    epochs=50,
    validation_split=0.2
)
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_18 (Embedding)    (None, 15, 128)           25472
#
#  bidirectional_8 (Bidirectio  (None, 256)              198144
#  nal)
#
#  repeat_vector_10 (RepeatVec  (None, 21, 256)          0
#  tor)
#
#  bidirectional_9 (Bidirectio  (None, 21, 256)          296448
#  nal)
#
#  dropout_9 (Dropout)         (None, 21, 256)           0
#
#  time_distributed_18 (TimeDi  (None, 21, 344)          88408
#  stributed)
#
#  time_distributed_19 (TimeDi  (None, 21, 344)          118680
#  stributed)
#
# =================================================================
# Total params: 727,152
# Trainable params: 727,152
# Non-trainable params: 0
# _________________________________________________________________
# None
# New Version of keras - Sequential has all expected attrs...
# Trying Tensorflow 2 version of keras...
# Final Model Loaded
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_19 (Embedding)    (None, 15, 128)           25472
#
#  bidirectional_10 (Bidirecti  (None, 256)              198144
#  onal)
#
#  repeat_vector_11 (RepeatVec  (None, 21, 256)          0
#  tor)
#
#  bidirectional_11 (Bidirecti  (None, 21, 256)          296448
#  onal)
#
#  dropout_10 (Dropout)        (None, 21, 256)           0
#
#  time_distributed_20 (TimeDi  (None, 21, 344)          88408
#  stributed)
#
#  time_distributed_21 (TimeDi  (None, 21, 344)          118680
#  stributed)
#
# =================================================================
# Total params: 727,152
# Trainable params: 727,152
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 108/108 [==============================] - 12s 70ms/step - loss: 2.8461 - accuracy: 0.4572 - val_loss: nan - val_accuracy: 0.5319
# Epoch 2/50
# 108/108 [==============================] - 7s 62ms/step - loss: 1.6593 - accuracy: 0.5740 - val_loss: nan - val_accuracy: 0.6288
# Epoch 3/50
# 108/108 [==============================] - 7s 63ms/step - loss: 1.3462 - accuracy: 0.6364 - val_loss: nan - val_accuracy: 0.6743
# Epoch 4/50
# 108/108 [==============================] - 7s 63ms/step - loss: 1.1975 - accuracy: 0.6674 - val_loss: nan - val_accuracy: 0.6844
# Epoch 5/50
# 108/108 [==============================] - 7s 63ms/step - loss: 1.1119 - accuracy: 0.6842 - val_loss: nan - val_accuracy: 0.7052
# Epoch 6/50
# 108/108 [==============================] - 7s 64ms/step - loss: 1.0392 - accuracy: 0.7007 - val_loss: nan - val_accuracy: 0.7167
# Epoch 7/50
# 108/108 [==============================] - 7s 64ms/step - loss: 0.9877 - accuracy: 0.7128 - val_loss: nan - val_accuracy: 0.7342
# Epoch 8/50
# 108/108 [==============================] - 7s 64ms/step - loss: 0.9321 - accuracy: 0.7268 - val_loss: nan - val_accuracy: 0.7473
# Epoch 9/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.8888 - accuracy: 0.7388 - val_loss: nan - val_accuracy: 0.7602
# Epoch 10/50
# 108/108 [==============================] - 7s 64ms/step - loss: 0.8439 - accuracy: 0.7509 - val_loss: nan - val_accuracy: 0.7748
# Epoch 11/50
# 108/108 [==============================] - 7s 64ms/step - loss: 0.8091 - accuracy: 0.7597 - val_loss: nan - val_accuracy: 0.7826
# Epoch 12/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.7664 - accuracy: 0.7698 - val_loss: nan - val_accuracy: 0.7912
# Epoch 13/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.7172 - accuracy: 0.7825 - val_loss: nan - val_accuracy: 0.8087
# Epoch 14/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.6740 - accuracy: 0.7941 - val_loss: nan - val_accuracy: 0.8185
# Epoch 15/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.6339 - accuracy: 0.8052 - val_loss: nan - val_accuracy: 0.8296
# Epoch 16/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.5974 - accuracy: 0.8164 - val_loss: nan - val_accuracy: 0.8436
# Epoch 17/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.5503 - accuracy: 0.8317 - val_loss: nan - val_accuracy: 0.8612
# Epoch 18/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.5134 - accuracy: 0.8433 - val_loss: nan - val_accuracy: 0.8728
# Epoch 19/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.4739 - accuracy: 0.8561 - val_loss: nan - val_accuracy: 0.8853
# Epoch 20/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.4369 - accuracy: 0.8675 - val_loss: nan - val_accuracy: 0.8937
# Epoch 21/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.4068 - accuracy: 0.8766 - val_loss: nan - val_accuracy: 0.8938
# Epoch 22/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.3814 - accuracy: 0.8840 - val_loss: nan - val_accuracy: 0.9078
# Epoch 23/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.3775 - accuracy: 0.8837 - val_loss: nan - val_accuracy: 0.9121
# Epoch 24/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.3311 - accuracy: 0.8995 - val_loss: nan - val_accuracy: 0.9215
# Epoch 25/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.3105 - accuracy: 0.9057 - val_loss: nan - val_accuracy: 0.9291
# Epoch 26/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.2905 - accuracy: 0.9121 - val_loss: nan - val_accuracy: 0.9333
# Epoch 27/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.2684 - accuracy: 0.9192 - val_loss: nan - val_accuracy: 0.9394
# Epoch 28/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.2538 - accuracy: 0.9240 - val_loss: nan - val_accuracy: 0.9412
# Epoch 29/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.2371 - accuracy: 0.9292 - val_loss: nan - val_accuracy: 0.9462
# Epoch 30/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.2249 - accuracy: 0.9329 - val_loss: nan - val_accuracy: 0.9504
# Epoch 31/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.2147 - accuracy: 0.9363 - val_loss: nan - val_accuracy: 0.9530
# Epoch 32/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.2001 - accuracy: 0.9408 - val_loss: nan - val_accuracy: 0.9541
# Epoch 33/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.1938 - accuracy: 0.9423 - val_loss: nan - val_accuracy: 0.9574 loss: 0.1943
# Epoch 34/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.1843 - accuracy: 0.9452 - val_loss: nan - val_accuracy: 0.9584
# Epoch 35/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.1737 - accuracy: 0.9485 - val_loss: nan - val_accuracy: 0.9591
# Epoch 36/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.1694 - accuracy: 0.9495 - val_loss: nan - val_accuracy: 0.9618
# Epoch 37/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.1613 - accuracy: 0.9519 - val_loss: nan - val_accuracy: 0.9628
# Epoch 38/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.1549 - accuracy: 0.9538 - val_loss: nan - val_accuracy: 0.9636
# Epoch 39/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.1480 - accuracy: 0.9560 - val_loss: nan - val_accuracy: 0.9632
# Epoch 40/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.1440 - accuracy: 0.9568 - val_loss: nan - val_accuracy: 0.9654
# Epoch 41/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.1374 - accuracy: 0.9590 - val_loss: nan - val_accuracy: 0.9647
# Epoch 42/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.1365 - accuracy: 0.9590 - val_loss: nan - val_accuracy: 0.9668
# Epoch 43/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.1282 - accuracy: 0.9617 - val_loss: nan - val_accuracy: 0.9669
# Epoch 44/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.1236 - accuracy: 0.9627 - val_loss: nan - val_accuracy: 0.9595
# Epoch 45/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.1216 - accuracy: 0.9636 - val_loss: nan - val_accuracy: 0.9702
# Epoch 46/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.1156 - accuracy: 0.9651 - val_loss: nan - val_accuracy: 0.9701
# Epoch 47/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.1137 - accuracy: 0.9658 - val_loss: nan - val_accuracy: 0.9714
# Epoch 48/50
# 108/108 [==============================] - 7s 66ms/step - loss: 0.1087 - accuracy: 0.9674 - val_loss: nan - val_accuracy: 0.9728
# Epoch 49/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.1053 - accuracy: 0.9683 - val_loss: nan - val_accuracy: 0.9723
# Epoch 50/50
# 108/108 [==============================] - 7s 65ms/step - loss: 0.1022 - accuracy: 0.9692 - val_loss: nan - val_accuracy: 0.9723

# %% [markdown]
# ## Prediction (IMPLEMENTATION)

# %%
def final_predictions(x, y, x_tk, y_tk):
    """
    Gets predictions using the final model
    :param x: Preprocessed English data
    :param y: Preprocessed French data
    :param x_tk: English tokenizer
    :param y_tk: French tokenizer
    """
    # TODO: Train neural network using model_final
    model = my_final_model
    
    ## DON'T EDIT ANYTHING BELOW THIS LINE
    y_id_to_word = {value: key for key, value in y_tk.word_index.items()}
    y_id_to_word[0] = '<PAD>'

    sentence = 'he saw a old yellow truck'
    sentence = [x_tk.word_index[word] for word in sentence.split()]
    sentence = pad_sequences([sentence], maxlen=x.shape[-1], padding='post')
    sentences = np.array([sentence[0], x[0]])
    tmp_sentences = pad(sentences, max_french_sequence_length)
    # [ACM] Editing per suggestion by knowledge.udacity.com
    predictions = model.predict(sentences, len(sentences))
    # predictions = model.predict(tmp_sentences, len(tmp_sentences))
    # [ACM] /edit

    print('Sample 1:')
    print(' '.join([y_id_to_word[np.argmax(x)] for x in predictions[0]]))
    print('Il a vu un vieux camion jaune')
    print('Sample 2:')
    print(' '.join([y_id_to_word[np.argmax(x)] for x in predictions[1]]))
    print(' '.join([y_id_to_word[np.max(x)] for x in y[0]]))


final_predictions(preproc_english_sentences, preproc_french_sentences, english_tokenizer, french_tokenizer)
# Out:
# Sample 1:
# il a vu un vieux camion jaune <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Il a vu un vieux camion jaune
# Sample 2:
# new jersey est parfois calme pendant l' automne et il est neigeux en avril <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# new jersey est parfois calme pendant l' automne et il est neigeux en avril <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %% [markdown]
# ## Submission
# When you're ready to submit, complete the following steps:
# 1. Review the [rubric](https://review.udacity.com/#!/rubrics/1004/view) to ensure your submission meets all requirements to pass
# 2. Generate an HTML version of this notebook
#
#   - Run the next cell to attempt automatic generation (this is the recommended method in Workspaces)
#   - Navigate to **FILE -> Download as -> HTML (.html)**
#   - Manually generate a copy using `nbconvert` from your shell terminal
# ```
# $ pip install nbconvert
# $ python -m nbconvert machine_translation.ipynb
# ```
#
# 3. Submit the project
#
#   - If you are in a Workspace, simply click the "Submit Project" button (bottom towards the right)
#
#   - Otherwise, add the following files into a zip archive and submit them
#   - `helper.py`
#   - `machine_translation.ipynb`
#   - `machine_translation.html`
#     - You can export the notebook by navigating to **File -> Download as -> HTML (.html)**.

# %% [markdown]
# ### Generate the html
#
# **Save your notebook before running the next cell to generate the HTML output.** Then submit your project.

# %%
# Save before you run this cell!
# !!jupyter nbconvert *.ipynb --to html

# %% [markdown]
# ## Optional Enhancements
#
# This project focuses on learning various network architectures for machine translation, but we don't evaluate the models according to best practices by splitting the data into separate test & training sets -- so the model accuracy is overstated. Use the [`sklearn.model_selection.train_test_split()`](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) function to create separate training & test datasets, then retrain each of the models using only the training set and evaluate the prediction accuracy using the hold out test set. Does the "best" model change?
